# %% [markdown]
# ## Attention Weight & Feature Map Visualization

# %%
import cv2
import os
from IPython.display import Video, display
from natsort import natsorted
import matplotlib.pyplot as plt

def create_video_from_frames(frame_folder, output_path, vis_name , fps=5):

    # Get a list of frame filenames sorted by name that include vis_name
    frames = natsorted([os.path.join(frame_folder, frame) for frame in os.listdir(frame_folder) if frame.endswith(('.png', '.jpg', '.jpeg')) and vis_name in frame])
    print(frames)
    if not frames:
        raise ValueError("No frames found with the specified vis_name in the filenames.")

    # Read the first frame to get the dimensions
    frame = cv2.imread(frames[0],)
    height, width, layers = frame.shape
    #frame = 1 - frame
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    #print(type(frame))
    #plt.imshow(frame)
    #plt.show()

    # Define the codec and create a VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    for _,frame in enumerate(frames):
        img = cv2.imread(frame)
        video.write(img)
        if _ == 116:
            break
        
        

    # Release the video writer object
    video.release()

# %%
# Example usage

save_dir = 'w_output_video_jet'
frame_folder = './data/Dataset/mot/visem/val/12/img1'
vis_name = ''

os.makedirs(save_dir,exist_ok=True)
output_path = os.path.join(save_dir,'input_video_12.mp4')
create_video_from_frames(frame_folder, output_path, vis_name, fps=5)
# Out:
# ['./data/Dataset/mot/visem/val/12/img1/000001.jpg', './data/Dataset/mot/visem/val/12/img1/000002.jpg', './data/Dataset/mot/visem/val/12/img1/000003.jpg', './data/Dataset/mot/visem/val/12/img1/000004.jpg', './data/Dataset/mot/visem/val/12/img1/000005.jpg', './data/Dataset/mot/visem/val/12/img1/000006.jpg', './data/Dataset/mot/visem/val/12/img1/000007.jpg', './data/Dataset/mot/visem/val/12/img1/000008.jpg', './data/Dataset/mot/visem/val/12/img1/000009.jpg', './data/Dataset/mot/visem/val/12/img1/000010.jpg', './data/Dataset/mot/visem/val/12/img1/000011.jpg', './data/Dataset/mot/visem/val/12/img1/000012.jpg', './data/Dataset/mot/visem/val/12/img1/000013.jpg', './data/Dataset/mot/visem/val/12/img1/000014.jpg', './data/Dataset/mot/visem/val/12/img1/000015.jpg', './data/Dataset/mot/visem/val/12/img1/000016.jpg', './data/Dataset/mot/visem/val/12/img1/000017.jpg', './data/Dataset/mot/visem/val/12/img1/000018.jpg', './data/Dataset/mot/visem/val/12/img1/000019.jpg', './data/Dataset/mot/visem/val/12/img1/000020.jpg', './data/Dataset/mot/visem/val/12/img1/000021.jpg', './data/Dataset/mot/visem/val/12/img1/000022.jpg', './data/Dataset/mot/visem/val/12/img1/000023.jpg', './data/Dataset/mot/visem/val/12/img1/000024.jpg', './data/Dataset/mot/visem/val/12/img1/000025.jpg', './data/Dataset/mot/visem/val/12/img1/000026.jpg', './data/Dataset/mot/visem/val/12/img1/000027.jpg', './data/Dataset/mot/visem/val/12/img1/000028.jpg', './data/Dataset/mot/visem/val/12/img1/000029.jpg',